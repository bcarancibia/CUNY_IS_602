# %% [markdown]
# This is an analysis and data clean up of two datasets from the Government of Honduras related to the country's foreign financial aid.

# %%
import csv
import re
values = []
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys

# %%
df_commitments = pd.read_excel("/users/bcarancibia/CUNY_IS_602/Project/Commitments_Honduras.xlsx")
df_commitments.head()
# Out:
#   CodigoPGC Actividadcreadaeldia Actividadeditadaeldia  \
# 0   TAIW025           20/03/2012            2013-08-30
# 1   TAIW035           20/03/2012            2014-12-02
# 2   TAIW034           20/03/2012            2013-08-30
# 3   ASDC008           20/03/2012            2013-03-05
# 4   OEIA008           20/03/2012            2013-05-13
#
#                                             Objetivo  \
# 0
# 1
# 2
# 3  Contribuir a mejorar la efectividad en la gest...
# 4
#
#                        IDsdeactividadyorganizaciones  \
# 0                           S/N (Gobierno de Taiwan)
# 1                           S/N (Gobierno de Taiwan)
# 2                           S/N (Gobierno de Taiwan)
# 3  HN26 (Cooperacion Suiza para el Desarrollo y l...
# 4      S/N (Organizacion de Estados Iberoamericanos)
#
#                               Descripciondelproyecto  \
# 0
# 1           Brindar cooperacion Tecnica agropecuaria
# 2                       Proyectos Embajada de Taiwan
# 3  El proyecto fortalece la relacion entre los di...
# 4
#
#                              SectorEjecutor  \
# 0                            Sector Publico
# 1  Autoadministrado por Socio al Desarrollo
# 2  Autoadministrado por Socio al Desarrollo
# 3                            Sector Privado
# 4  Autoadministrado por Socio al Desarrollo
#
#                            NombredeProyecto/Programa       Etapa Fechadefirma  \
# 0                    Proyectos Despacho Primera Dama  Finalizado   2011-01-01
# 1                              Mision Tecnica Taiwan  Finalizado          NaT
# 2                       Proyectos Embajada de Taiwan  Finalizado   2011-01-01
# 3                      Traspaso de Gobiernos Locales  Finalizado   2009-01-01
# 4  Mejora de la calidad educativa en la poblacion...  Finalizado   2010-01-04
#
#       ...      September2014Commitments        Total AMPID TITLE LATITUDE  \
# 0     ...                             0   355000.000   NaN   NaN      NaN
# 1     ...                             0  2744338.270   NaN   NaN      NaN
# 2     ...                             0   350000.000   NaN   NaN      NaN
# 3     ...                             0   476000.000   NaN   NaN      NaN
# 4     ...                             0   131371.519   NaN   NaN      NaN
#
#   LONGITUDE TYPE DESCRIPTION Unnamed: 193 Unnamed: 194
# 0       NaN  NaN         NaN          NaN          NaN
# 1       NaN  NaN         NaN          NaN          NaN
# 2       NaN  NaN         NaN          NaN          NaN
# 3       NaN  NaN         NaN          NaN          NaN
# 4       NaN  NaN         NaN          NaN          NaN
#
# [5 rows x 195 columns]

# %%
df_locations = pd.read_excel("/users/bcarancibia/CUNY_IS_602/Project/Locations_Honduras.xlsx")
df_locations.head()
